# %%
import cv2
import argparse
import imutils
import time
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from PIL import Image
from imutils.video import VideoStream

# %%
MODEL_DIR = '../../model_mv/'
#MODEL_DIR = '../../model/'
IMG_HEIGHT = 256
IMG_WIDTH = 256
CLASS_NAMES = ['correctly-masked', 'not-masked', 'incorrectly-masked']
CORRECTLY_MASKED = CLASS_NAMES[0]
NOT_MASKED = CLASS_NAMES[1]
INCORRECTLY_MASKED = CLASS_NAMES[2]

# %%
model = keras.models.load_model(MODEL_DIR)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                4194368
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 4,220,131
# Trainable params: 4,220,131
# Non-trainable params: 0
# _________________________________________________________________

# %%
def get_face(img, x, y, w, h, width, height) -> Image.Image: 
    crop_img = img[y:y+h, x:x+w]
    cv2.imshow("cropped", crop_img)
    # Convert image from GBR to RGB
    rgb_img = cv2.cvtColor(crop_img, cv2.COLOR_BGR2RGB)
    pil_img = Image.fromarray(rgb_img)
    newsize = (width, height)
    resized_img = pil_img.resize(newsize)
    return resized_img

def predict(resized_img, class_names):
    img_array = keras.preprocessing.image.img_to_array(resized_img)
    img_array = tf.expand_dims(img_array, 0)
    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])
    prediction = class_names[np.argmax(score)]
    confidence = 100 * np.max(score)
    return prediction, confidence
    
def get_color(prediction):
    green = (36,255,12)
    red = (0,0,255)
    yellow = (0,255,255)
    if prediction == CORRECTLY_MASKED:
        color = green
    elif prediction == NOT_MASKED:
        color = red
    else:
        color = yellow

    return color

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
print("[INFO] starting video stream ...")
cv2.namedWindow("preview")
cap = cv2.VideoCapture(0)
_, img = cap.read()
if (cap.isOpened() == False):
    print("[ERROR] Unable to read camera feed ...")

while True:
    _, img = cap.read()
    # Convert to grayscale (haarcascade works with grayscale)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    for (x, y, w, h) in faces:
        resized_img = get_face(img, x, y, w, h, IMG_WIDTH, IMG_HEIGHT)
        prediction, confidence= predict(resized_img, CLASS_NAMES)
        color = get_color(prediction)
        print(f'{prediction}: {confidence}')
        cv2.rectangle(img, (x, y), (x+w, y+h), color, 2)
        cv2.putText(img, str(prediction), (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
        
    cv2.imshow('img', img)
    key = cv2.waitKey(1) & 0xFF
    if key == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
exit()
# Out:
# [INFO] starting video stream ...
# not-masked: 99.99996423721313
# not-masked: 99.99996423721313
# not-masked: 99.99994039535522
# not-masked: 99.99991655349731
# not-masked: 99.99992847442627
# not-masked: 99.99994039535522
# not-masked: 99.99992847442627
# not-masked: 99.99995231628418
# not-masked: 99.99992847442627
# not-masked: 99.99995231628418
# not-masked: 99.99995231628418
# not-masked: 99.99995231628418
# not-masked: 99.99992847442627
# not-masked: 99.99992847442627
# not-masked: 99.99991655349731
# not-masked: 99.99992847442627
# not-masked: 99.99991655349731
# not-masked: 99.9998927116394
# not-masked: 99.99994039535522
# not-masked: 99.99995231628418
# not-masked: 99.99995231628418
# not-masked: 99.99994039535522
# not-masked: 99.99996423721313
# not-masked: 99.99996423721313
# not-masked: 99.99996423721313
# not-masked: 99.99996423721313
# not-masked: 99.99995231628418
# not-masked: 99.99995231628418
# not-masked: 99.99996423721313
# not-masked: 99.99996423721313
# not-masked: 99.99995231628418
# not-masked: 99.99995231628418
# not-masked: 99.99996423721313
# not-masked: 99.99996423721313
# not-masked: 99.99996423721313
# not-masked: 99.99996423721313
# not-masked: 99.99996423721313
# not-masked: 99.99992847442627
# not-masked: 99.99995231628418
# not-masked: 99.99990463256836
# not-masked: 99.99992847442627
# not-masked: 99.99995231628418
# not-masked: 99.99995231628418
# not-masked: 99.99984502792358
# not-masked: 99.99973773956299
# not-masked: 99.99973773956299
# not-masked: 99.99961853027344
# not-masked: 99.99974966049194
# not-masked: 99.99961853027344
# not-masked: 99.99943971633911
# not-masked: 99.99959468841553
# not-masked: 99.99970197677612
# incorrectly-masked: 54.146742820739746
# not-masked: 99.99967813491821
# incorrectly-masked: 71.28832936286926
# not-masked: 99.99920129776001
# correctly-masked: 75.2193808555603
# not-masked: 99.99963045120239
# correctly-masked: 99.98372793197632
# not-masked: 99.98313188552856
# not-masked: 99.99852180480957
# not-masked: 99.99885559082031
# not-masked: 99.99927282333374
# not-masked: 99.99916553497314
# not-masked: 99.99918937683105
# not-masked: 99.9994158744812
# not-masked: 99.9997615814209
# not-masked: 99.99980926513672
# not-masked: 99.99982118606567
# not-masked: 99.9995470046997
# not-masked: 99.99971389770508
# not-masked: 99.99972581863403
# not-masked: 99.99959468841553
# not-masked: 99.99967813491821
# not-masked: 99.99964237213135
# not-masked: 99.99966621398926
# not-masked: 99.99967813491821
# not-masked: 99.99942779541016
# not-masked: 99.9997615814209
# not-masked: 99.99974966049194
# not-masked: 99.99970197677612
# not-masked: 99.99943971633911
# not-masked: 99.99960660934448
# not-masked: 99.99967813491821
# not-masked: 99.99973773956299
# incorrectly-masked: 74.17671084403992
# correctly-masked: 99.98370409011841
# correctly-masked: 99.97522234916687
# correctly-masked: 99.97794032096863
# correctly-masked: 99.98026490211487
# correctly-masked: 99.9654769897461
# correctly-masked: 99.94838237762451
# correctly-masked: 99.9756395816803
# correctly-masked: 99.91675615310669
# correctly-masked: 99.97557997703552
# correctly-masked: 99.95773434638977
# correctly-masked: 99.97416138648987
# correctly-masked: 99.90553259849548
# correctly-masked: 99.97314810752869
# correctly-masked: 99.77265000343323
# correctly-masked: 99.95506405830383
# correctly-masked: 99.64220523834229
# not-masked: 99.9996542930603
# correctly-masked: 99.8877227306366
# not-masked: 99.99961853027344
# correctly-masked: 99.93228912353516
# not-masked: 55.333518981933594
# not-masked: 99.99916553497314
# correctly-masked: 99.94812607765198
# not-masked: 99.99653100967407
# not-masked: 99.9983549118042
# correctly-masked: 99.97506737709045
# not-masked: 99.99748468399048
# correctly-masked: 99.93852376937866
# not-masked: 99.99767541885376
# correctly-masked: 99.94413256645203
# not-masked: 99.99674558639526
# correctly-masked: 99.97900128364563
# not-masked: 99.99673366546631
# not-masked: 99.99676942825317
# correctly-masked: 99.97796416282654
# not-masked: 99.99755620956421
# correctly-masked: 99.97479319572449
# correctly-masked: 99.94754195213318
# not-masked: 99.99803304672241
# not-masked: 99.99847412109375
# correctly-masked: 99.9133050441742
# correctly-masked: 99.96296167373657
# not-masked: 99.99823570251465
# not-masked: 99.99743700027466
# not-masked: 99.99814033508301
# correctly-masked: 99.86782670021057
# not-masked: 99.99829530715942
# correctly-masked: 99.96868371963501
# not-masked: 99.687659740448
# not-masked: 99.99865293502808
# correctly-masked: 99.95896220207214
# not-masked: 99.96217489242554
# not-masked: 99.99897480010986
# correctly-masked: 99.94800686836243
# not-masked: 99.97307658195496
# not-masked: 99.99909400939941
# correctly-masked: 99.94869232177734
# not-masked: 99.99902248382568
# correctly-masked: 99.96169805526733
# not-masked: 99.99991655349731
# not-masked: 99.99897480010986
# correctly-masked: 99.92690682411194
# not-masked: 99.99997615814209
# not-masked: 99.99878406524658
# correctly-masked: 99.84524250030518
# correctly-masked: 99.93757605552673
# not-masked: 99.99856948852539
# correctly-masked: 99.92594122886658
# not-masked: 99.99849796295166
# not-masked: 99.99868869781494
# correctly-masked: 99.9524474143982
# not-masked: 99.99970197677612
# not-masked: 99.99903440475464
# correctly-masked: 99.93168115615845
# not-masked: 99.99881982803345
# correctly-masked: 99.92021918296814
# not-masked: 99.99825954437256
# correctly-masked: 99.88027811050415
# not-masked: 99.99864101409912
# not-masked: 99.9972939491272
# correctly-masked: 99.92982149124146
# not-masked: 99.9998688697815
# not-masked: 99.99877214431763
# correctly-masked: 99.91588592529297
# not-masked: 99.99898672103882
# correctly-masked: 99.96432065963745
# not-masked: 99.99938011169434
# correctly-masked: 99.82094764709473
# not-masked: 99.99943971633911
# correctly-masked: 99.85918402671814
# not-masked: 99.99803304672241
# not-masked: 99.99942779541016
# correctly-masked: 99.93120431900024
# not-masked: 99.99940395355225
# correctly-masked: 99.94028806686401
# not-masked: 99.99881982803345
# correctly-masked: 99.94277358055115
# not-masked: 99.99897480010986
# correctly-masked: 99.94338154792786
# correctly-masked: 99.94718432426453
# not-masked: 99.99892711639404
# not-masked: 99.99920129776001
# correctly-masked: 99.96273517608643
# not-masked: 99.99908208847046
# correctly-masked: 99.95642304420471
# not-masked: 99.9968409538269
# correctly-masked: 99.87741112709045
# not-masked: 99.99876022338867
# correctly-masked: 99.85450506210327
# not-masked: 99.99878406524658
# correctly-masked: 99.92743134498596
# not-masked: 99.99920129776001
# correctly-masked: 99.95216131210327
# not-masked: 99.99896287918091
# correctly-masked: 99.94484782218933
# not-masked: 99.93579983711243
# correctly-masked: 99.97547268867493
# correctly-masked: 83.20719003677368
# correctly-masked: 99.9657154083252
# incorrectly-masked: 52.41394639015198
# correctly-masked: 99.94783997535706
# incorrectly-masked: 50.87255239486694
# correctly-masked: 99.97126460075378
# correctly-masked: 59.830909967422485
# correctly-masked: 99.93903636932373
# incorrectly-masked: 73.31568598747253
# correctly-masked: 99.98027682304382
# incorrectly-masked: 84.11558270454407
# correctly-masked: 99.93426203727722
# not-masked: 99.98520612716675
# correctly-masked: 99.79897737503052
# not-masked: 99.9990701675415
# correctly-masked: 99.89149570465088
# not-masked: 99.99940395355225
# correctly-masked: 99.89387392997742
# not-masked: 99.99979734420776
# correctly-masked: 99.85626339912415
# not-masked: 99.9998688697815
# correctly-masked: 99.93969202041626
# incorrectly-masked: 66.10831022262573
# correctly-masked: 99.94569420814514
# correctly-masked: 72.40241169929504
# correctly-masked: 99.9629259109497
# correctly-masked: 60.11430025100708
# correctly-masked: 99.9298095703125
# incorrectly-masked: 51.615023612976074
# correctly-masked: 99.9346911907196
# correctly-masked: 64.13983702659607
# correctly-masked: 99.94161128997803
# correctly-masked: 80.1211953163147
# correctly-masked: 99.95471835136414
# correctly-masked: 71.11735939979553
# correctly-masked: 99.89475607872009
# not-masked: 99.99827146530151
# correctly-masked: 66.25068187713623
# correctly-masked: 99.90758895874023
# correctly-masked: 58.29737186431885
# correctly-masked: 99.89243149757385
# correctly-masked: 63.05081248283386
# not-masked: 100.0
# correctly-masked: 99.94980096817017
# incorrectly-masked: 84.47211384773254
# correctly-masked: 99.8597800731659
# correctly-masked: 99.91651773452759
# correctly-masked: 99.94667172431946
# correctly-masked: 99.96442794799805
# correctly-masked: 99.92936849594116
# correctly-masked: 99.95811581611633
# correctly-masked: 99.98136162757874
# correctly-masked: 99.98347759246826
# correctly-masked: 99.96355772018433
# correctly-masked: 99.96627569198608
# correctly-masked: 99.96737241744995
# correctly-masked: 99.94908571243286
# correctly-masked: 99.95951056480408
# incorrectly-masked: 87.94972896575928
# correctly-masked: 99.97153878211975
# correctly-masked: 63.77496123313904
# correctly-masked: 99.97202754020691
# correctly-masked: 86.53349280357361
# correctly-masked: 99.96054768562317
# correctly-masked: 83.21071863174438
# correctly-masked: 99.93002414703369
# incorrectly-masked: 67.98572540283203
# correctly-masked: 99.93079900741577
# incorrectly-masked: 90.43549299240112
# correctly-masked: 99.92977380752563
# incorrectly-masked: 84.26865935325623
# correctly-masked: 99.90507960319519
# incorrectly-masked: 91.71313643455505
# correctly-masked: 99.86997842788696
# correctly-masked: 80.85097670555115
# correctly-masked: 99.95088577270508
# incorrectly-masked: 96.07923626899719
# correctly-masked: 99.92347955703735
# incorrectly-masked: 99.59271550178528
# correctly-masked: 99.92337226867676
# incorrectly-masked: 98.14403057098389
# correctly-masked: 99.91627931594849
# incorrectly-masked: 51.0850191116333
# incorrectly-masked: 98.25772643089294
# correctly-masked: 99.82509016990662
# not-masked: 75.93721747398376
# not-masked: 62.92523741722107
# incorrectly-masked: 95.08222341537476
# correctly-masked: 99.86773133277893
# incorrectly-masked: 94.5668876171112
# correctly-masked: 99.7624933719635
# not-masked: 95.22629380226135
# incorrectly-masked: 89.54312801361084
# correctly-masked: 99.78952407836914
# not-masked: 99.99935626983643
# not-masked: 92.73732900619507
# incorrectly-masked: 85.88690161705017
# correctly-masked: 99.82813596725464
# not-masked: 70.28334140777588
# incorrectly-masked: 95.51392793655396
# correctly-masked: 99.79169964790344
# not-masked: 98.59916567802429
# not-masked: 58.99091958999634
# correctly-masked: 99.90528225898743
# not-masked: 80.13983964920044
# correctly-masked: 99.87181425094604
# not-masked: 99.43397641181946
# incorrectly-masked: 93.75057220458984
# correctly-masked: 99.83775615692139
# not-masked: 99.50048327445984
# incorrectly-masked: 87.34329342842102
# correctly-masked: 99.82016086578369
# not-masked: 98.32472205162048
# not-masked: 100.0
# incorrectly-masked: 94.53355669975281
# correctly-masked: 99.81690645217896
# not-masked: 93.41508150100708
# not-masked: 100.0
# incorrectly-masked: 95.82547545433044
# not-masked: 100.0
# correctly-masked: 99.93044137954712
# not-masked: 100.0
# not-masked: 96.00837826728821
# incorrectly-masked: 99.3118405342102
# correctly-masked: 99.94569420814514
# not-masked: 96.76222801208496
# incorrectly-masked: 98.82293939590454
# not-masked: 100.0
# correctly-masked: 99.90828037261963
# not-masked: 96.07988595962524
# incorrectly-masked: 98.65315556526184
# correctly-masked: 99.93728995323181
# incorrectly-masked: 95.70380449295044
# correctly-masked: 99.92044568061829
# not-masked: 100.0
# not-masked: 78.44356298446655
# incorrectly-masked: 98.76054525375366
# correctly-masked: 99.94282126426697
# incorrectly-masked: 99.03050661087036
# correctly-masked: 99.93178844451904
# not-masked: 90.20981788635254
# incorrectly-masked: 98.40982556343079
# correctly-masked: 99.9743640422821
# not-masked: 99.99998807907104
# not-masked: 99.99997615814209
# incorrectly-masked: 97.30800986289978
# correctly-masked: 99.9998927116394
# not-masked: 99.99998807907104
# not-masked: 99.18545484542847
# incorrectly-masked: 94.48205232620239
# correctly-masked: 99.9026894569397
# incorrectly-masked: 82.53421187400818
# incorrectly-masked: 98.8163411617279
# correctly-masked: 99.03541803359985
# not-masked: 86.55782341957092
# not-masked: 100.0
# incorrectly-masked: 99.40783977508545
# correctly-masked: 99.61283206939697
# not-masked: 89.58303332328796
# not-masked: 100.0
# incorrectly-masked: 99.56791996955872
# correctly-masked: 99.83865022659302
# not-masked: 100.0
# not-masked: 98.92569184303284
# incorrectly-masked: 99.30394291877747
# correctly-masked: 99.97699856758118
# not-masked: 87.86758780479431
# incorrectly-masked: 97.71983623504639
# correctly-masked: 99.89818930625916
# not-masked: 65.02010822296143
# incorrectly-masked: 97.4239706993103
# correctly-masked: 99.96695518493652
# not-masked: 96.25347852706909
# incorrectly-masked: 91.90890789031982
# not-masked: 83.0645740032196
# incorrectly-masked: 92.59506464004517
# not-masked: 96.90983295440674
# incorrectly-masked: 94.49086785316467
# correctly-masked: 99.87364411354065
# not-masked: 98.44979643821716
# incorrectly-masked: 98.32320213317871
# correctly-masked: 99.97124075889587
# not-masked: 78.07971835136414
# incorrectly-masked: 97.4641740322113
# correctly-masked: 99.94885921478271
# not-masked: 83.77937078475952
# incorrectly-masked: 99.02211427688599
# not-masked: 100.0
# correctly-masked: 99.97702240943909
# not-masked: 100.0
# not-masked: 85.70886850357056
# incorrectly-masked: 96.33679389953613
# correctly-masked: 99.9112069606781
# not-masked: 100.0
# incorrectly-masked: 92.69551038742065
# correctly-masked: 99.90384578704834
# not-masked: 100.0
# not-masked: 85.27678847312927
# incorrectly-masked: 95.64178586006165
# correctly-masked: 99.94298815727234
# incorrectly-masked: 91.89301133155823
# correctly-masked: 98.82461428642273
# not-masked: 100.0
# incorrectly-masked: 94.81584429740906
# correctly-masked: 99.69026446342468
# incorrectly-masked: 86.80211901664734
# correctly-masked: 99.84696507453918
# incorrectly-masked: 93.95378232002258
# correctly-masked: 99.35318231582642
# incorrectly-masked: 87.90678977966309
# not-masked: 100.0
# incorrectly-masked: 94.09834742546082
# incorrectly-masked: 81.80339932441711
# not-masked: 99.99998807907104
# incorrectly-masked: 91.95448756217957
# incorrectly-masked: 96.94921970367432
# incorrectly-masked: 97.74354100227356
# incorrectly-masked: 98.12003970146179
# correctly-masked: 98.99381399154663
# incorrectly-masked: 94.21401619911194
# correctly-masked: 98.52263331413269
# incorrectly-masked: 97.38865494728088
# correctly-masked: 97.58161306381226
# incorrectly-masked: 84.38669443130493
# incorrectly-masked: 94.20650601387024
# incorrectly-masked: 86.61214709281921
# incorrectly-masked: 95.58060765266418
# incorrectly-masked: 94.29118633270264
# incorrectly-masked: 91.83059334754944
# correctly-masked: 99.58769083023071
# not-masked: 99.93876218795776
# incorrectly-masked: 64.5881712436676
# correctly-masked: 99.11105632781982
# incorrectly-masked: 93.92810463905334
# incorrectly-masked: 89.70955014228821
# correctly-masked: 99.97327923774719
# incorrectly-masked: 97.82741665840149
# incorrectly-masked: 97.31568098068237
# incorrectly-masked: 98.95211458206177
# incorrectly-masked: 95.19338011741638
# incorrectly-masked: 96.91548347473145
# not-masked: 99.99349117279053
# incorrectly-masked: 98.04158806800842
# not-masked: 99.99991655349731
# incorrectly-masked: 97.90531992912292
# not-masked: 100.0
# incorrectly-masked: 96.44832015037537
# not-masked: 98.71519804000854
# incorrectly-masked: 95.24520635604858
# incorrectly-masked: 99.856036901474
# incorrectly-masked: 99.23375248908997
# correctly-masked: 99.99983310699463
# incorrectly-masked: 96.87681794166565
# not-masked: 100.0
# correctly-masked: 99.97590184211731
# incorrectly-masked: 97.26029634475708
# correctly-masked: 99.78066086769104
# incorrectly-masked: 97.76590466499329
# not-masked: 100.0
# correctly-masked: 97.95223474502563
# incorrectly-masked: 74.017733335495
# correctly-masked: 99.9186098575592
# incorrectly-masked: 97.29672074317932
# correctly-masked: 99.8176097869873
# incorrectly-masked: 70.19293904304504
# correctly-masked: 99.9201238155365
# incorrectly-masked: 54.71044182777405
# correctly-masked: 99.95284080505371
# incorrectly-masked: 70.96818685531616
# correctly-masked: 99.97050166130066
# incorrectly-masked: 88.76582980155945
# incorrectly-masked: 90.72872996330261
# incorrectly-masked: 94.09499168395996
# correctly-masked: 99.98650550842285
# incorrectly-masked: 92.85674691200256
# incorrectly-masked: 95.76970338821411
# correctly-masked: 99.93783235549927
# incorrectly-masked: 34.9861204624176
# incorrectly-masked: 84.06241536140442
# incorrectly-masked: 93.39653849601746
# not-masked: 73.15139174461365
# incorrectly-masked: 89.79799151420593
# incorrectly-masked: 87.67685294151306
# correctly-masked: 99.90131855010986
# incorrectly-masked: 88.082754611969
# not-masked: 100.0
# correctly-masked: 99.92867112159729
# incorrectly-masked: 85.0149929523468
# correctly-masked: 99.90257024765015
# incorrectly-masked: 75.45028924942017
# correctly-masked: 99.8846173286438
# incorrectly-masked: 89.63379263877869
# not-masked: 100.0
# correctly-masked: 99.85283613204956
# incorrectly-masked: 79.41703200340271
# correctly-masked: 99.87002611160278
# incorrectly-masked: 71.6942548751831
# correctly-masked: 99.86763596534729
# incorrectly-masked: 89.90972638130188
# correctly-masked: 99.93064403533936
# incorrectly-masked: 91.36196374893188
# correctly-masked: 99.91768002510071
# incorrectly-masked: 93.36192011833191
# correctly-masked: 99.97696280479431
# incorrectly-masked: 88.44612240791321
# incorrectly-masked: 90.74349403381348
# correctly-masked: 99.99221563339233
# incorrectly-masked: 96.46923542022705
# correctly-masked: 99.99068975448608
# incorrectly-masked: 73.05183410644531
# correctly-masked: 99.98356103897095
# incorrectly-masked: 83.53312015533447
# correctly-masked: 99.9724805355072
# not-masked: 94.6777880191803
# incorrectly-masked: 95.59261798858643
# correctly-masked: 99.97525811195374
# incorrectly-masked: 88.49231004714966
# correctly-masked: 99.96356964111328
# not-masked: 97.42685556411743
# incorrectly-masked: 79.3178915977478
# correctly-masked: 99.93890523910522
# not-masked: 90.04505276679993
# incorrectly-masked: 85.15007495880127
# correctly-masked: 99.9805748462677
# incorrectly-masked: 80.20117282867432
# correctly-masked: 99.96089339256287
# incorrectly-masked: 98.40017557144165
# correctly-masked: 99.69550371170044
# incorrectly-masked: 89.14462327957153
# correctly-masked: 99.93767142295837
# incorrectly-masked: 91.83069467544556
# correctly-masked: 99.86317753791809
# incorrectly-masked: 92.39873886108398
# correctly-masked: 99.93402361869812
# not-masked: 80.75209259986877
# incorrectly-masked: 93.03619861602783
# correctly-masked: 99.87118244171143
# incorrectly-masked: 84.542715549469
# correctly-masked: 99.68583583831787
# not-masked: 85.67327857017517
# incorrectly-masked: 77.1061897277832
# correctly-masked: 99.87505674362183
# incorrectly-masked: 67.926424741745
# correctly-masked: 99.68108534812927
# not-masked: 60.93480587005615
# correctly-masked: 99.71174001693726
# not-masked: 54.72942590713501
# correctly-masked: 99.93958473205566
# not-masked: 89.06199932098389
# correctly-masked: 99.93625283241272
# not-masked: 96.20426893234253
# incorrectly-masked: 78.159099817276
# correctly-masked: 99.96411800384521
# not-masked: 99.99972581863403
# incorrectly-masked: 73.56752753257751
# correctly-masked: 99.98689889907837
# not-masked: 99.71833825111389
# incorrectly-masked: 53.34450006484985
# correctly-masked: 99.97734427452087
# not-masked: 90.32676815986633
# correctly-masked: 99.98505115509033
# incorrectly-masked: 86.12948656082153
# correctly-masked: 99.97715353965759
# incorrectly-masked: 74.06200766563416
# correctly-masked: 99.98871088027954
# not-masked: 99.6803879737854
# incorrectly-masked: 93.70585083961487
# correctly-masked: 99.99099969863892
# incorrectly-masked: 82.92211294174194
# correctly-masked: 99.99053478240967
# incorrectly-masked: 90.0085985660553
# correctly-masked: 99.98809099197388
# incorrectly-masked: 91.0831093788147
# not-masked: 100.0
# correctly-masked: 99.98252987861633
# not-masked: 60.56548357009888
# correctly-masked: 99.99009370803833
# not-masked: 73.02224040031433
# not-masked: 52.68256664276123
# correctly-masked: 99.98407363891602
# not-masked: 99.96321201324463
# correctly-masked: 99.9898910522461
# not-masked: 99.99868869781494
# correctly-masked: 99.97708201408386
# not-masked: 99.99234676361084
# correctly-masked: 99.97027516365051
# not-masked: 99.97822642326355
# correctly-masked: 99.98670816421509
# not-masked: 99.96918439865112
# incorrectly-masked: 49.05864894390106
# not-masked: 99.96263980865479
# correctly-masked: 99.91225600242615
# not-masked: 99.96577501296997
# correctly-masked: 99.94457364082336
# not-masked: 99.99916553497314
# correctly-masked: 99.93922710418701
# correctly-masked: 75.6976068019867
# correctly-masked: 99.77838397026062
# correctly-masked: 79.51709032058716
# correctly-masked: 99.8336672782898
# correctly-masked: 88.3637011051178
# correctly-masked: 81.68079853057861
# correctly-masked: 71.40684723854065
# correctly-masked: 58.93915295600891
# correctly-masked: 75.49230456352234
# correctly-masked: 54.72325086593628
# correctly-masked: 85.09299755096436
# correctly-masked: 69.1463828086853
# incorrectly-masked: 99.99774694442749
# correctly-masked: 79.77981567382812
# incorrectly-masked: 99.9974250793457
# correctly-masked: 74.87387657165527
# incorrectly-masked: 93.70653629302979
# correctly-masked: 76.11231803894043
# incorrectly-masked: 86.7206871509552
# correctly-masked: 61.931782960891724
# incorrectly-masked: 95.38146257400513
# correctly-masked: 67.04072952270508
# incorrectly-masked: 91.17628931999207
# correctly-masked: 75.12216567993164
# not-masked: 87.92712092399597
# correctly-masked: 84.12134051322937
# not-masked: 97.14493751525879
# not-masked: 100.0
# correctly-masked: 71.28130793571472
# incorrectly-masked: 99.64355230331421
# correctly-masked: 71.57708406448364
# incorrectly-masked: 58.182740211486816
# correctly-masked: 78.66939902305603
# not-masked: 53.01002860069275
# correctly-masked: 77.43595242500305
# incorrectly-masked: 99.80276226997375
# correctly-masked: 81.71296715736389
# not-masked: 57.58093595504761
# not-masked: 100.0
# correctly-masked: 75.51214694976807
# not-masked: 86.63185238838196
# correctly-masked: 80.09878396987915
# not-masked: 87.79199123382568
# correctly-masked: 59.718501567840576
# not-masked: 78.63222360610962
# not-masked: 99.99288320541382
# correctly-masked: 72.01406955718994
# not-masked: 76.95816159248352
# correctly-masked: 83.2676351070404
# incorrectly-masked: 99.91432428359985
# correctly-masked: 76.70459151268005
# incorrectly-masked: 98.35239052772522
# correctly-masked: 80.09921908378601
# incorrectly-masked: 99.9738872051239
# not-masked: 100.0
# correctly-masked: 93.5098946094513
# not-masked: 76.18336081504822
# correctly-masked: 86.12191081047058
# incorrectly-masked: 99.55839514732361
# correctly-masked: 80.16476631164551
# correctly-masked: 99.99891519546509
# not-masked: 100.0
# correctly-masked: 79.72193360328674
# incorrectly-masked: 82.88334608078003
# not-masked: 100.0
# not-masked: 100.0
# correctly-masked: 84.61288213729858
# not-masked: 100.0
# correctly-masked: 85.99622845649719
# correctly-masked: 99.70851540565491
# correctly-masked: 86.87735199928284
# correctly-masked: 99.859219789505
# not-masked: 99.99399185180664
# correctly-masked: 88.86187672615051
# correctly-masked: 99.71678853034973
# not-masked: 64.2307698726654
# correctly-masked: 81.18197321891785
# not-masked: 59.458863735198975
# correctly-masked: 78.40139865875244
# correctly-masked: 68.73130798339844
# correctly-masked: 62.867772579193115
# correctly-masked: 68.90787482261658
# incorrectly-masked: 52.638983726501465
# correctly-masked: 76.74418687820435
# correctly-masked: 82.93373584747314
# incorrectly-masked: 76.83659791946411
# not-masked: 99.83963370323181
# not-masked: 99.99328851699829
# not-masked: 99.98725652694702
# incorrectly-masked: 73.72432351112366
# correctly-masked: 92.05728769302368
# incorrectly-masked: 54.529666900634766
# correctly-masked: 93.31424236297607
# incorrectly-masked: 86.33948564529419
# correctly-masked: 89.43292498588562
# not-masked: 99.99823570251465
# incorrectly-masked: 68.41980814933777
# not-masked: 99.99358654022217
# correctly-masked: 84.91429686546326
# correctly-masked: 78.85927557945251
# correctly-masked: 81.44339919090271
# correctly-masked: 88.40253949165344
# correctly-masked: 86.68954968452454
# correctly-masked: 86.26764416694641
# correctly-masked: 84.84492301940918
# correctly-masked: 89.73451852798462
# correctly-masked: 76.83579921722412
# not-masked: 99.9955415725708
# not-masked: 99.99901056289673
# incorrectly-masked: 63.57749700546265
# not-masked: 99.99958276748657
# not-masked: 99.97137188911438
# not-masked: 90.16345143318176
# not-masked: 99.44397211074829
# not-masked: 57.5793981552124
# not-masked: 99.99442100524902
# not-masked: 99.85643029212952
# not-masked: 99.9659776687622
# not-masked: 99.9893069267273
# incorrectly-masked: 67.89289116859436
# not-masked: 99.98432397842407
# not-masked: 99.37161803245544
# not-masked: 99.71025586128235
# incorrectly-masked: 60.66972613334656
# incorrectly-masked: 53.28277349472046
# correctly-masked: 58.46972465515137
# correctly-masked: 62.60635256767273
# correctly-masked: 56.839364767074585
# incorrectly-masked: 51.881688833236694
# incorrectly-masked: 53.58501672744751
# correctly-masked: 59.86037850379944
# correctly-masked: 77.49800682067871
# incorrectly-masked: 76.23469233512878
# correctly-masked: 85.97105741500854
# incorrectly-masked: 74.21717047691345
# correctly-masked: 70.24206519126892
# correctly-masked: 68.95697712898254
# not-masked: 62.50060200691223
# incorrectly-masked: 58.7446391582489
# not-masked: 82.62264132499695
# incorrectly-masked: 91.08784794807434
# correctly-masked: 52.69950032234192
# incorrectly-masked: 50.31733512878418
# correctly-masked: 68.73757243156433
# incorrectly-masked: 75.50784349441528
# incorrectly-masked: 78.68780493736267
# incorrectly-masked: 93.94289255142212
# incorrectly-masked: 89.51391577720642
# incorrectly-masked: 55.11770844459534
# not-masked: 78.08017134666443
# correctly-masked: 66.68281555175781
# incorrectly-masked: 81.22063279151917
# not-masked: 99.96441602706909
# incorrectly-masked: 55.41837215423584
# not-masked: 99.76039528846741
# not-masked: 99.99910593032837
# not-masked: 99.99879598617554
# incorrectly-masked: 71.19391560554504
# incorrectly-masked: 83.55410099029541
# not-masked: 99.99839067459106
# not-masked: 99.99805688858032
# not-masked: 99.97500777244568
# incorrectly-masked: 82.11317658424377
# incorrectly-masked: 86.78013682365417
# incorrectly-masked: 83.62972140312195
# incorrectly-masked: 85.38677096366882
# not-masked: 99.9950647354126
# incorrectly-masked: 76.40887498855591
# incorrectly-masked: 78.0543863773346
# incorrectly-masked: 74.59588050842285
# incorrectly-masked: 70.88738679885864
# incorrectly-masked: 73.06165099143982
# not-masked: 99.99991655349731
# incorrectly-masked: 70.82096338272095
# incorrectly-masked: 79.39097285270691
# incorrectly-masked: 67.21246838569641
# incorrectly-masked: 79.5023500919342
# incorrectly-masked: 78.2311737537384
# incorrectly-masked: 76.39133334159851
# not-masked: 99.99927282333374
# incorrectly-masked: 58.49260687828064
# incorrectly-masked: 80.69047927856445
# incorrectly-masked: 90.40163159370422
# incorrectly-masked: 76.9505500793457
# incorrectly-masked: 85.3558897972107
# incorrectly-masked: 77.61216163635254
# incorrectly-masked: 78.18435430526733
# incorrectly-masked: 88.8525664806366
# incorrectly-masked: 78.07930707931519
# incorrectly-masked: 89.6345853805542
# not-masked: 99.80574250221252
# incorrectly-masked: 91.93212389945984
# incorrectly-masked: 79.56746220588684
# correctly-masked: 51.32322311401367
# incorrectly-masked: 71.25700116157532
# not-masked: 99.88059997558594
# incorrectly-masked: 82.33039975166321
# incorrectly-masked: 85.91778874397278
# not-masked: 72.2342312335968
# incorrectly-masked: 84.80122685432434
# not-masked: 97.28083610534668
# correctly-masked: 55.44174313545227
# not-masked: 99.96893405914307
# correctly-masked: 51.738208532333374
# incorrectly-masked: 53.68095636367798
# incorrectly-masked: 96.91661596298218
# incorrectly-masked: 58.94377827644348
# incorrectly-masked: 95.86710929870605
# incorrectly-masked: 97.45659828186035
# incorrectly-masked: 75.06384253501892
# incorrectly-masked: 76.65531039237976
# incorrectly-masked: 99.93652701377869
# incorrectly-masked: 78.51819396018982
# not-masked: 99.99997615814209
# incorrectly-masked: 69.80417966842651
# not-masked: 99.99997615814209
# incorrectly-masked: 76.92784667015076
# not-masked: 99.99997615814209
# incorrectly-masked: 73.20036292076111
# not-masked: 99.99997615814209
# incorrectly-masked: 78.29415202140808
# not-masked: 99.99997615814209
# incorrectly-masked: 73.30934405326843
# not-masked: 99.99997615814209
# incorrectly-masked: 74.27211403846741
# not-masked: 99.99997615814209
# incorrectly-masked: 89.90483283996582
# incorrectly-masked: 89.06494975090027
# not-masked: 100.0
# incorrectly-masked: 87.00835108757019
# correctly-masked: 64.60787057876587
# correctly-masked: 99.9007523059845
# not-masked: 100.0
# correctly-masked: 98.97827506065369
# not-masked: 99.99996423721313
# not-masked: 100.0
# correctly-masked: 97.59225845336914
# correctly-masked: 99.16083216667175
# not-masked: 54.975903034210205
# correctly-masked: 98.85122776031494
# correctly-masked: 98.48124980926514
# correctly-masked: 56.3457727432251
# correctly-masked: 99.80377554893494
# correctly-masked: 99.93665814399719
# incorrectly-masked: 98.80077838897705
# correctly-masked: 98.80704879760742
# correctly-masked: 99.7035264968872
# incorrectly-masked: 80.89848160743713
# incorrectly-masked: 43.76513957977295
# correctly-masked: 99.80484247207642
# correctly-masked: 99.39295053482056
# correctly-masked: 99.84278678894043
# correctly-masked: 99.88403916358948
# correctly-masked: 99.65785145759583
# correctly-masked: 99.81725215911865
# correctly-masked: 99.7911274433136
# correctly-masked: 99.64131712913513
# correctly-masked: 98.95350337028503
# correctly-masked: 99.78212118148804
# correctly-masked: 98.53041768074036
# correctly-masked: 99.8050332069397
# correctly-masked: 99.76125955581665
# correctly-masked: 99.88600015640259
# not-masked: 97.40967154502869
# correctly-masked: 99.23259019851685
# not-masked: 99.99992847442627
# incorrectly-masked: 86.51236891746521
# correctly-masked: 99.53846335411072
# correctly-masked: 99.82972741127014
# not-masked: 99.99728202819824
# incorrectly-masked: 78.19387912750244
# incorrectly-masked: 76.44784450531006
# correctly-masked: 64.70451951026917
# incorrectly-masked: 76.14818215370178
# not-masked: 56.50835037231445
