# %%
import cv2
import argparse
import imutils
import time
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from PIL import Image
from imutils.video import VideoStream

# %%
MODEL_DIR = '../../model/'
IMG_HEIGHT = 256
IMG_WIDTH = 256
CLASS_NAMES = ['correctly-masked', 'not-masked', 'uncorrectly-masked']

# %%
model = keras.models.load_model(MODEL_DIR)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 131072)            0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4194336
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 4,200,003
# Trainable params: 4,200,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
def get_face(img, x, y, w, h) -> Image.Image: 
    crop_img = img[y:y+h, x:x+w]
    cv2.imshow("cropped", crop_img)
    # Convert image from GBR to RGB
    rgb_img = cv2.cvtColor(crop_img, cv2.COLOR_BGR2RGB)
    pil_img = Image.fromarray(rgb_img)
    newsize = (IMG_WIDTH, IMG_HEIGHT)
    resized_img = pil_img.resize(newsize)
    return resized_img

def predict(resized_img):
    img_array = keras.preprocessing.image.img_to_array(resized_img)
    img_array = tf.expand_dims(img_array, 0)
    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])
    prediction = CLASS_NAMES[np.argmax(score)]
    confidence = 100 * np.max(score)
    return prediction, confidence
    
def get_color(prediction) -> tuple:
    green = (36,255,12)
    if prediction == CLASS_NAMES[0]:
        color = green
    elif prediction == CLASS_NAMES[1]:
        color = (0, 255, 0)
    else:
        color = (0, 0, 255)

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
print("[INFO] starting video stream ...")
cap = cv2.VideoCapture(0)
_, img = cap.read()
if (cap.isOpened() == False):
    print("[ERROR] Unable to read camera feed ...")

while True:
    _, img = cap.read()
    # Convert to grayscale (haarcascade works with grayscale)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    for (x, y, w, h) in faces:
        resized_img = get_face(img, x, y, w, h)
        prediction, confidence= predict(resized_img)
        color = get_color(prediction)
        print(f'{prediction}: {confidence}')
        cv2.rectangle(img, (x, y), (x+w, y+h), (36,255,12), 2)
        cv2.putText(img, str(prediction), (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
        
    cv2.imshow('img', img)
    key = cv2.waitKey(1) & 0xFF
    # if the `q` key was pressed, break from the loop
    if key == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
exit()
# Out:
# [INFO] starting video stream ...
# not-masked: 95.63136100769043
# not-masked: 93.21862459182739
# not-masked: 92.62665510177612
# not-masked: 91.81388020515442
# not-masked: 97.84598350524902
# not-masked: 94.45226788520813
# not-masked: 93.56792569160461
# not-masked: 93.55699419975281
# not-masked: 94.50055360794067
# not-masked: 97.71719574928284
# not-masked: 97.64727354049683
# not-masked: 98.06468486785889
# not-masked: 99.10477995872498
# not-masked: 98.93608689308167
# not-masked: 99.08711314201355
# not-masked: 98.5969066619873
# not-masked: 98.846834897995
# not-masked: 98.6871600151062
# not-masked: 98.53945970535278
# not-masked: 98.71121048927307
# not-masked: 96.5469241142273
# not-masked: 97.94514775276184
# not-masked: 94.91588473320007
# not-masked: 93.55576038360596
# not-masked: 91.38045907020569
# not-masked: 92.65714287757874
# not-masked: 94.1960334777832
# not-masked: 93.63782405853271
# not-masked: 99.70223307609558
# not-masked: 99.10900592803955
# not-masked: 97.0333993434906
# not-masked: 96.83389663696289
# not-masked: 95.36663889884949
# not-masked: 90.94683527946472
# not-masked: 83.80622863769531
# not-masked: 68.40441823005676
# not-masked: 60.816603899002075
# uncorrectly-masked: 79.33050394058228
# uncorrectly-masked: 62.71516680717468
# not-masked: 97.4463403224945
# not-masked: 97.78273701667786
# not-masked: 95.82207798957825
# not-masked: 96.23351097106934
# uncorrectly-masked: 69.14585828781128
# uncorrectly-masked: 70.83699703216553
# uncorrectly-masked: 69.36783790588379
# uncorrectly-masked: 69.65490579605103
# uncorrectly-masked: 60.52837371826172
# uncorrectly-masked: 60.776931047439575
# uncorrectly-masked: 67.37836599349976
# uncorrectly-masked: 57.4965238571167
# uncorrectly-masked: 57.117509841918945
# uncorrectly-masked: 62.45540380477905
# uncorrectly-masked: 64.11544680595398
# uncorrectly-masked: 66.41950011253357
# uncorrectly-masked: 58.4384560585022
# uncorrectly-masked: 54.77939248085022
# uncorrectly-masked: 63.897716999053955
# uncorrectly-masked: 55.863720178604126
# uncorrectly-masked: 62.85969018936157
# uncorrectly-masked: 72.24964499473572
# uncorrectly-masked: 76.20272040367126
# uncorrectly-masked: 80.13628721237183
# uncorrectly-masked: 74.91066455841064
# uncorrectly-masked: 72.01707363128662
# uncorrectly-masked: 73.05985689163208
# uncorrectly-masked: 78.64500284194946
# uncorrectly-masked: 83.64219665527344
# uncorrectly-masked: 85.52165627479553
# uncorrectly-masked: 87.29356527328491
# uncorrectly-masked: 81.22660517692566
# uncorrectly-masked: 78.34621667861938
# uncorrectly-masked: 73.52606654167175
# uncorrectly-masked: 61.96942925453186
# uncorrectly-masked: 63.13841938972473
# not-masked: 47.82467782497406
# not-masked: 69.46716904640198
# not-masked: 97.6738452911377
# not-masked: 91.08304381370544
# not-masked: 90.85761308670044
# not-masked: 87.59153485298157
# not-masked: 90.49059748649597
# not-masked: 76.57749056816101
# not-masked: 96.01665139198303
# not-masked: 85.23979783058167
# not-masked: 80.94335794448853
# not-masked: 92.46466755867004
# not-masked: 88.90774250030518
# not-masked: 94.98922824859619
# not-masked: 87.85619735717773
# not-masked: 91.31696224212646
# not-masked: 97.11838364601135
# not-masked: 95.00381350517273
# not-masked: 95.97163200378418
# not-masked: 99.15750622749329
# not-masked: 92.76099801063538
# not-masked: 99.74325299263
# not-masked: 99.49889779090881
# not-masked: 95.5136775970459
# not-masked: 99.83970522880554
# not-masked: 80.2355706691742
# not-masked: 90.22536873817444
# not-masked: 99.88057613372803
# not-masked: 93.39219927787781
# not-masked: 94.36367750167847
# not-masked: 93.63309741020203
# not-masked: 93.90413165092468
# not-masked: 96.15731239318848
# not-masked: 97.5231945514679
# not-masked: 96.02739214897156
# not-masked: 97.57894277572632
# not-masked: 95.26119232177734
# not-masked: 90.78710675239563
# not-masked: 99.09533262252808
# not-masked: 94.75860595703125
# not-masked: 99.99699592590332
# not-masked: 93.55137944221497
# not-masked: 95.63131928443909
# not-masked: 96.77132964134216
# not-masked: 98.53906631469727
# not-masked: 98.85410666465759
# not-masked: 95.3927993774414
# not-masked: 95.86187601089478
# not-masked: 99.06733632087708
# not-masked: 98.92666339874268
# not-masked: 98.71053695678711
# not-masked: 98.77051115036011
# not-masked: 99.07796382904053
# not-masked: 99.04154539108276
# not-masked: 99.02926683425903
# not-masked: 98.97586107254028
# not-masked: 99.07835721969604
# not-masked: 99.15517568588257
# not-masked: 99.16947484016418
# not-masked: 99.28142428398132
# not-masked: 99.16016459465027
# not-masked: 99.27950501441956
# not-masked: 99.11912083625793
# not-masked: 99.09364581108093
# not-masked: 99.17043447494507
# not-masked: 99.427729845047
# not-masked: 93.37874054908752
# not-masked: 94.33497190475464
# not-masked: 96.72126173973083
# not-masked: 95.52407264709473
# not-masked: 96.47064805030823
# not-masked: 99.72867965698242
# not-masked: 97.72059917449951
# not-masked: 97.48409986495972
# not-masked: 99.9067485332489
# not-masked: 94.77214813232422
# not-masked: 99.72339272499084
# not-masked: 93.45956444740295
# not-masked: 87.76378035545349
# not-masked: 96.81367874145508
# not-masked: 96.41167521476746
# not-masked: 98.80962371826172
# not-masked: 99.76713061332703
# not-masked: 98.69778752326965
# not-masked: 99.96267557144165
# not-masked: 94.47178244590759
# not-masked: 94.05670166015625
# not-masked: 94.42130923271179
# not-masked: 93.4160053730011
# not-masked: 93.07315349578857
# not-masked: 94.8387086391449
# not-masked: 94.7540819644928
# not-masked: 92.41661429405212
# not-masked: 94.2455530166626
# not-masked: 96.53177261352539
# not-masked: 93.78653168678284
# not-masked: 96.51815295219421
# not-masked: 98.08343052864075
# not-masked: 98.32062721252441
# not-masked: 97.72840142250061
# not-masked: 97.78028726577759
# not-masked: 97.87702560424805
# not-masked: 97.41857051849365
# not-masked: 97.76813983917236
# not-masked: 97.71108627319336
# not-masked: 97.72589206695557
# not-masked: 97.70837426185608
# not-masked: 97.0255196094513
# not-masked: 97.27665781974792
# not-masked: 97.22985625267029
# not-masked: 95.04898190498352
# not-masked: 95.35857439041138
# not-masked: 99.31578040122986
# uncorrectly-masked: 50.33484697341919
# not-masked: 95.64200043678284
# not-masked: 99.2805540561676
# not-masked: 96.39183282852173
# not-masked: 92.36623048782349
# not-masked: 87.51558065414429
# not-masked: 86.48743033409119
# not-masked: 88.88493180274963
# not-masked: 87.6075804233551
# not-masked: 85.69766283035278
# not-masked: 92.80470609664917
# not-masked: 91.69177412986755
# not-masked: 90.86461663246155
# not-masked: 91.12728238105774
# not-masked: 88.32122087478638
# not-masked: 85.05750894546509
# not-masked: 93.48582029342651
# not-masked: 95.90242505073547
# not-masked: 98.59808683395386
# not-masked: 98.5454797744751
# not-masked: 69.49979066848755
# not-masked: 98.89217615127563
# not-masked: 99.97701048851013
# uncorrectly-masked: 53.98871898651123
# not-masked: 98.32187294960022
# not-masked: 98.17652702331543
# not-masked: 83.18423628807068
# not-masked: 63.027048110961914
# not-masked: 99.06929135322571
# uncorrectly-masked: 86.26546859741211
# not-masked: 99.6461570262909
# not-masked: 99.3595540523529
# not-masked: 99.45317506790161
# not-masked: 98.62642884254456
# not-masked: 99.24557209014893
# not-masked: 99.21667575836182
# not-masked: 98.73538613319397
# not-masked: 97.54226207733154
# not-masked: 97.77939915657043
# not-masked: 98.08263778686523
# not-masked: 98.33270907402039
# not-masked: 98.46662282943726
# not-masked: 97.16786742210388
# not-masked: 97.4405825138092
# not-masked: 97.55532741546631
# not-masked: 97.71996140480042
# not-masked: 98.67829084396362
# not-masked: 98.97691011428833
# not-masked: 99.25270080566406
# not-masked: 99.05315637588501
# not-masked: 97.80172109603882
# not-masked: 98.27370643615723
# not-masked: 97.5665032863617
# not-masked: 98.9385724067688
# not-masked: 99.48188662528992
# not-masked: 98.8840401172638
# not-masked: 97.88428544998169
# not-masked: 97.39824533462524
# not-masked: 97.82693982124329
# not-masked: 96.66536450386047
# not-masked: 91.7173445224762
# not-masked: 96.05106115341187
# not-masked: 98.41782450675964
# not-masked: 93.60206723213196
# not-masked: 92.9412841796875
# not-masked: 78.05165648460388
# not-masked: 98.55925440788269
# not-masked: 98.31463694572449
# not-masked: 97.3010778427124
# not-masked: 97.97945618629456
# not-masked: 95.83242535591125
# not-masked: 91.14487767219543
# not-masked: 95.9315299987793
# not-masked: 93.60988140106201
# not-masked: 95.90126276016235
# not-masked: 99.66357350349426
# not-masked: 73.80369901657104
# not-masked: 73.08010458946228
# not-masked: 85.18778085708618
# not-masked: 71.00260257720947
# not-masked: 77.05163359642029
# uncorrectly-masked: 56.030404567718506
# uncorrectly-masked: 72.95835018157959
# uncorrectly-masked: 69.01766061782837
# uncorrectly-masked: 73.89305233955383
# uncorrectly-masked: 71.94873094558716
# uncorrectly-masked: 65.02707600593567
# uncorrectly-masked: 49.77969825267792
# uncorrectly-masked: 51.15647912025452
# uncorrectly-masked: 57.367104291915894
# uncorrectly-masked: 68.16070675849915
# uncorrectly-masked: 73.27038645744324
# uncorrectly-masked: 77.11960077285767
# uncorrectly-masked: 67.01546907424927
# uncorrectly-masked: 70.37403583526611
# uncorrectly-masked: 56.633514165878296
# uncorrectly-masked: 61.533182859420776
# uncorrectly-masked: 61.650002002716064
# uncorrectly-masked: 76.83565616607666
# not-masked: 92.50781536102295
# not-masked: 97.50535488128662
# uncorrectly-masked: 68.71259212493896
# uncorrectly-masked: 74.52518343925476
# uncorrectly-masked: 77.39700675010681
# uncorrectly-masked: 62.73420453071594
# uncorrectly-masked: 66.74511432647705
# uncorrectly-masked: 77.06288695335388
# uncorrectly-masked: 72.38373756408691
# uncorrectly-masked: 47.584593296051025
# uncorrectly-masked: 64.36781287193298
# uncorrectly-masked: 59.34669375419617
# uncorrectly-masked: 47.23502695560455
# uncorrectly-masked: 48.95397424697876
# uncorrectly-masked: 68.13564896583557
# correctly-masked: 46.01978659629822
# uncorrectly-masked: 48.92313480377197
# uncorrectly-masked: 52.91669964790344
# uncorrectly-masked: 46.069204807281494
# correctly-masked: 45.18937170505524
# uncorrectly-masked: 58.03627371788025
# uncorrectly-masked: 49.031201004981995
# correctly-masked: 46.31818234920502
# correctly-masked: 44.712647795677185
# uncorrectly-masked: 50.54880976676941
# correctly-masked: 52.80225872993469
# uncorrectly-masked: 44.57789659500122
# uncorrectly-masked: 46.93921208381653
# uncorrectly-masked: 53.3719539642334
# uncorrectly-masked: 47.36722111701965
# correctly-masked: 43.776002526283264
# uncorrectly-masked: 48.47525656223297
# uncorrectly-masked: 59.082889556884766
# uncorrectly-masked: 76.910400390625
# uncorrectly-masked: 60.74461340904236
# not-masked: 95.99797129631042
# uncorrectly-masked: 70.23005485534668
# uncorrectly-masked: 69.00845170021057
# uncorrectly-masked: 53.49624156951904
# uncorrectly-masked: 58.75341296195984
# uncorrectly-masked: 51.343828439712524
# uncorrectly-masked: 70.07637619972229
# uncorrectly-masked: 57.94911980628967
# uncorrectly-masked: 64.80836272239685
# uncorrectly-masked: 51.12732648849487
# uncorrectly-masked: 58.3324134349823
# uncorrectly-masked: 61.90481781959534
# uncorrectly-masked: 73.42216372489929
# uncorrectly-masked: 60.192930698394775
# uncorrectly-masked: 55.922889709472656
# uncorrectly-masked: 65.30064940452576
# uncorrectly-masked: 53.84528040885925
# correctly-masked: 61.01871132850647
# uncorrectly-masked: 63.10049891471863
# uncorrectly-masked: 64.6124541759491
# uncorrectly-masked: 48.88896942138672
# uncorrectly-masked: 64.35360908508301
# uncorrectly-masked: 73.15934300422668
# uncorrectly-masked: 63.76203894615173
