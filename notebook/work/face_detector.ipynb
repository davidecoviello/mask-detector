# %%
import cv2
import argparse
import imutils
import time
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from PIL import Image
from imutils.video import VideoStream

# %%
MODEL_DIR = '../../model/'
IMG_HEIGHT = 256
IMG_WIDTH = 256
CLASS_NAMES = ['correctly-masked', 'not-masked', 'uncorrectly-masked']
CORRECTLY_MASKED = CLASS_NAMES[0]
NOT_MASKED = CLASS_NAMES[1]
INCORRECTLY_MASKED = CLASS_NAMES[2]

# %%
model = keras.models.load_model(MODEL_DIR)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 131072)            0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4194336
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 4,200,003
# Trainable params: 4,200,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
def get_face(img, x, y, w, h) -> Image.Image: 
    crop_img = img[y:y+h, x:x+w]
    cv2.imshow("cropped", crop_img)
    # Convert image from GBR to RGB
    rgb_img = cv2.cvtColor(crop_img, cv2.COLOR_BGR2RGB)
    pil_img = Image.fromarray(rgb_img)
    newsize = (IMG_WIDTH, IMG_HEIGHT)
    resized_img = pil_img.resize(newsize)
    return resized_img

def predict(resized_img):
    img_array = keras.preprocessing.image.img_to_array(resized_img)
    img_array = tf.expand_dims(img_array, 0)
    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])
    prediction = CLASS_NAMES[np.argmax(score)]
    confidence = 100 * np.max(score)
    return prediction, confidence
    
def get_color(prediction):
    green = (36,255,12)
    red = (0,0,255)
    yellow = (0,255,255)
    if prediction == CORRECTLY_MASKED:
        color = green
    elif prediction == NOT_MASKED:
        color = red
    else:
        color = yellow

    return color

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
print("[INFO] starting video stream ...")
cap = cv2.VideoCapture(0)
_, img = cap.read()
if (cap.isOpened() == False):
    print("[ERROR] Unable to read camera feed ...")

while True:
    _, img = cap.read()
    # Convert to grayscale (haarcascade works with grayscale)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    for (x, y, w, h) in faces:
        resized_img = get_face(img, x, y, w, h)
        prediction, confidence= predict(resized_img)
        color = get_color(prediction)
        print(f'{prediction}: {confidence}')
        cv2.rectangle(img, (x, y), (x+w, y+h), color, 2)
        cv2.putText(img, str(prediction), (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
        
    cv2.imshow('img', img)
    key = cv2.waitKey(1) & 0xFF
    # if the `q` key was pressed, break from the loop
    if key == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
exit()
# Out:
# [INFO] starting video stream ...
# uncorrectly-masked: 68.0630624294281
# not-masked: 99.04879927635193
# not-masked: 99.57077503204346
# not-masked: 98.55818152427673
# not-masked: 98.15537929534912
# not-masked: 98.9238977432251
# not-masked: 98.96089434623718
# not-masked: 98.27719330787659
# not-masked: 98.91468286514282
# not-masked: 99.19126033782959
# not-masked: 99.67832565307617
# not-masked: 53.832608461380005
# not-masked: 93.21887493133545
# not-masked: 97.9516327381134
# not-masked: 95.3223168849945
# not-masked: 97.79127836227417
# not-masked: 98.54904413223267
# not-masked: 99.82364177703857
# not-masked: 99.25893545150757
# not-masked: 99.0626573562622
# not-masked: 98.4835684299469
# not-masked: 97.84020781517029
# not-masked: 63.03759217262268
# not-masked: 84.92312431335449
# not-masked: 94.93793845176697
# not-masked: 96.86786532402039
# not-masked: 90.7029390335083
# not-masked: 74.92262721061707
# uncorrectly-masked: 52.03178524971008
# not-masked: 77.1487832069397
# not-masked: 97.62923121452332
# not-masked: 62.34614849090576
# not-masked: 99.91841912269592
# not-masked: 80.7195782661438
# not-masked: 98.09927344322205
# not-masked: 98.55270385742188
# correctly-masked: 80.11896014213562
# not-masked: 99.99997615814209
# not-masked: 99.99997615814209
# not-masked: 99.99995231628418
# not-masked: 99.99908208847046
# not-masked: 99.99994039535522
# uncorrectly-masked: 97.4369466304779
# not-masked: 99.99998807907104
# not-masked: 99.99997615814209
# not-masked: 99.99997615814209
# not-masked: 99.99988079071045
# uncorrectly-masked: 98.0428397655487
# not-masked: 99.99121427536011
# uncorrectly-masked: 99.65992569923401
# not-masked: 99.99971389770508
# not-masked: 99.99983310699463
# not-masked: 99.99997615814209
# not-masked: 99.99998807907104
# not-masked: 99.99998807907104
# not-masked: 99.99995231628418
# not-masked: 100.0
# not-masked: 100.0
# not-masked: 99.42069053649902
# not-masked: 98.26073050498962
# not-masked: 98.74209761619568
# not-masked: 99.9247670173645
# not-masked: 90.68241119384766
# not-masked: 70.96638083457947
# not-masked: 73.11838865280151
# not-masked: 56.602734327316284
# uncorrectly-masked: 69.35275793075562
# uncorrectly-masked: 69.37288641929626
# uncorrectly-masked: 85.25592088699341
# uncorrectly-masked: 83.2139790058136
# not-masked: 99.6418833732605
# uncorrectly-masked: 81.00319504737854
# uncorrectly-masked: 86.09230518341064
# correctly-masked: 93.97718906402588
# uncorrectly-masked: 82.30521082878113
# correctly-masked: 96.55864834785461
# uncorrectly-masked: 83.68246555328369
# correctly-masked: 93.50516200065613
# uncorrectly-masked: 58.19699764251709
# correctly-masked: 95.4806923866272
# uncorrectly-masked: 55.172234773635864
# correctly-masked: 91.3200318813324
# uncorrectly-masked: 64.55081701278687
# uncorrectly-masked: 69.03641819953918
# correctly-masked: 94.70155835151672
# not-masked: 99.99446868896484
# uncorrectly-masked: 70.52395939826965
# correctly-masked: 92.77286529541016
# uncorrectly-masked: 55.79493045806885
# correctly-masked: 82.61446356773376
# uncorrectly-masked: 60.78144907951355
# correctly-masked: 93.8429594039917
# not-masked: 64.8416519165039
# correctly-masked: 91.99028611183167
# not-masked: 75.2419114112854
# correctly-masked: 95.43371200561523
# not-masked: 76.23131275177002
# correctly-masked: 92.97618269920349
# not-masked: 96.69189453125
# correctly-masked: 88.79824876785278
# not-masked: 97.78819680213928
# correctly-masked: 94.79115605354309
# not-masked: 99.60021376609802
# correctly-masked: 79.70811724662781
# not-masked: 99.84707236289978
# correctly-masked: 84.6731424331665
# not-masked: 99.60787892341614
# correctly-masked: 88.5357677936554
# not-masked: 98.24147820472717
# correctly-masked: 83.28183889389038
# not-masked: 92.97775030136108
# not-masked: 99.60989952087402
# not-masked: 99.71379041671753
# not-masked: 99.52076077461243
# uncorrectly-masked: 93.10437440872192
# not-masked: 84.19761061668396
# not-masked: 99.6049702167511
# not-masked: 96.32317423820496
# not-masked: 99.64938759803772
# not-masked: 80.76856136322021
# not-masked: 99.45828318595886
# not-masked: 62.047773599624634
# not-masked: 55.114829540252686
# not-masked: 70.72519063949585
# not-masked: 71.83600664138794
# not-masked: 55.87801933288574
# uncorrectly-masked: 75.92757940292358
# uncorrectly-masked: 76.73298716545105
# uncorrectly-masked: 75.73891282081604
# uncorrectly-masked: 74.72818493843079
# uncorrectly-masked: 83.85254144668579
# uncorrectly-masked: 80.24700880050659
# uncorrectly-masked: 70.95553874969482
# uncorrectly-masked: 88.57824802398682
# uncorrectly-masked: 93.3102548122406
# uncorrectly-masked: 96.12275958061218
# uncorrectly-masked: 97.02622294425964
# uncorrectly-masked: 97.63721823692322
# uncorrectly-masked: 98.68696331977844
# uncorrectly-masked: 98.3644425868988
# uncorrectly-masked: 99.33288097381592
# uncorrectly-masked: 99.13663268089294
# uncorrectly-masked: 99.3180513381958
# uncorrectly-masked: 99.08842444419861
# uncorrectly-masked: 98.41713309288025
# uncorrectly-masked: 96.58886790275574
# uncorrectly-masked: 97.19022512435913
# uncorrectly-masked: 96.47031426429749
# uncorrectly-masked: 92.99570918083191
# uncorrectly-masked: 62.04907298088074
# uncorrectly-masked: 65.59162735939026
# not-masked: 50.25925636291504
# uncorrectly-masked: 52.56251096725464
# not-masked: 49.66856241226196
# uncorrectly-masked: 51.98267698287964
# uncorrectly-masked: 75.61749815940857
# uncorrectly-masked: 79.37684059143066
# uncorrectly-masked: 68.14658045768738
# uncorrectly-masked: 52.79475450515747
# uncorrectly-masked: 83.6391270160675
# uncorrectly-masked: 82.11764097213745
# uncorrectly-masked: 74.85818266868591
# not-masked: 62.8123939037323
# uncorrectly-masked: 50.827085971832275
# uncorrectly-masked: 69.7924256324768
# uncorrectly-masked: 57.20037817955017
# uncorrectly-masked: 50.06631016731262
# uncorrectly-masked: 85.40380597114563
# uncorrectly-masked: 82.29130506515503
# not-masked: 53.87448072433472
# uncorrectly-masked: 71.35397791862488
# not-masked: 56.79754018783569
# uncorrectly-masked: 64.67468738555908
# uncorrectly-masked: 76.90191268920898
# uncorrectly-masked: 68.87030601501465
# uncorrectly-masked: 67.16619729995728
# uncorrectly-masked: 65.01818299293518
# uncorrectly-masked: 78.80180478096008
# uncorrectly-masked: 80.5230438709259
# uncorrectly-masked: 76.98004841804504
# uncorrectly-masked: 94.25539970397949
# uncorrectly-masked: 80.35547733306885
# uncorrectly-masked: 58.494919538497925
# not-masked: 74.21454191207886
# uncorrectly-masked: 90.82178473472595
# uncorrectly-masked: 97.09522724151611
# not-masked: 88.24883103370667
# uncorrectly-masked: 93.87117624282837
# uncorrectly-masked: 98.22160005569458
# uncorrectly-masked: 98.82398843765259
# uncorrectly-masked: 97.14376330375671
# uncorrectly-masked: 98.50903749465942
# uncorrectly-masked: 98.52342009544373
# uncorrectly-masked: 98.37408661842346
# uncorrectly-masked: 98.45027327537537
# uncorrectly-masked: 98.68418574333191
# uncorrectly-masked: 99.25360679626465
# uncorrectly-masked: 99.63980913162231
# uncorrectly-masked: 99.00562763214111
# uncorrectly-masked: 98.89060258865356
# uncorrectly-masked: 99.68382120132446
# uncorrectly-masked: 99.36174154281616
# uncorrectly-masked: 99.6266782283783
# uncorrectly-masked: 99.68462586402893
# uncorrectly-masked: 99.58678483963013
# uncorrectly-masked: 99.74368214607239
# uncorrectly-masked: 99.76630210876465
# uncorrectly-masked: 99.48858618736267
# uncorrectly-masked: 99.48496222496033
# uncorrectly-masked: 92.1857476234436
# not-masked: 73.78233075141907
# not-masked: 74.39966201782227
# not-masked: 50.7698118686676
# not-masked: 95.18475532531738
# not-masked: 95.45347690582275
# not-masked: 95.9589958190918
# not-masked: 99.5512306690216
# not-masked: 89.24686312675476
# uncorrectly-masked: 81.31079077720642
# uncorrectly-masked: 99.52801465988159
# uncorrectly-masked: 99.55262541770935
# uncorrectly-masked: 99.68531727790833
# uncorrectly-masked: 98.69088530540466
# uncorrectly-masked: 98.83069396018982
# uncorrectly-masked: 98.79372715950012
# uncorrectly-masked: 99.74510073661804
# uncorrectly-masked: 99.22147393226624
# not-masked: 98.87961149215698
# not-masked: 61.07068061828613
# not-masked: 66.16472005844116
# not-masked: 72.84814119338989
# not-masked: 97.45500087738037
# not-masked: 99.62371587753296
# not-masked: 99.79392886161804
# not-masked: 99.73356127738953
# not-masked: 99.80019927024841
# not-masked: 99.70019459724426
# not-masked: 99.97034668922424
# not-masked: 99.82549548149109
# not-masked: 99.96792078018188
# not-masked: 99.7420072555542
# not-masked: 99.9660849571228
# not-masked: 99.81368780136108
# not-masked: 99.94174242019653
# not-masked: 99.6333360671997
# not-masked: 99.98712539672852
# not-masked: 99.69327449798584
# not-masked: 99.96559619903564
# not-masked: 99.77346658706665
# not-masked: 99.97435212135315
# not-masked: 99.78430271148682
# not-masked: 99.99043941497803
# not-masked: 99.71628785133362
# not-masked: 99.95439648628235
# not-masked: 99.71436858177185
# not-masked: 99.99611377716064
# correctly-masked: 98.36762547492981
# not-masked: 99.99920129776001
# uncorrectly-masked: 70.88906764984131
# not-masked: 94.25263404846191
# not-masked: 99.95457530021667
# not-masked: 99.73377585411072
# not-masked: 99.5105504989624
# not-masked: 99.86339211463928
# not-masked: 99.8993456363678
# not-masked: 99.97472167015076
# uncorrectly-masked: 71.67099714279175
# uncorrectly-masked: 85.00096797943115
# uncorrectly-masked: 92.46852993965149
# uncorrectly-masked: 90.07962942123413
# uncorrectly-masked: 89.89740014076233
# uncorrectly-masked: 94.18121576309204
# not-masked: 92.32118725776672
# uncorrectly-masked: 90.2705729007721
# not-masked: 95.67617774009705
# uncorrectly-masked: 91.64617657661438
# not-masked: 94.95881795883179
# not-masked: 97.04801440238953
# not-masked: 97.7995753288269
# uncorrectly-masked: 88.6137843132019
# not-masked: 96.3175117969513
# uncorrectly-masked: 94.3314254283905
# correctly-masked: 99.87152814865112
# uncorrectly-masked: 87.32275366783142
# correctly-masked: 99.41526055335999
# uncorrectly-masked: 93.98205280303955
# correctly-masked: 99.19936656951904
# correctly-masked: 55.16113042831421
# uncorrectly-masked: 77.08985209465027
# uncorrectly-masked: 78.9969265460968
# not-masked: 96.21992707252502
# uncorrectly-masked: 89.16427493095398
# uncorrectly-masked: 85.31132340431213
# correctly-masked: 90.2667760848999
# uncorrectly-masked: 65.8528983592987
# correctly-masked: 70.69782614707947
# not-masked: 76.37267112731934
# correctly-masked: 56.740158796310425
# not-masked: 71.79369330406189
# correctly-masked: 61.631715297698975
# not-masked: 63.93665671348572
# uncorrectly-masked: 58.02450776100159
# not-masked: 56.48670792579651
# not-masked: 85.6044590473175
# not-masked: 65.28437733650208
# uncorrectly-masked: 62.30108141899109
# not-masked: 70.32718062400818
# not-masked: 99.661785364151
# uncorrectly-masked: 69.29323077201843
# not-masked: 63.34226727485657
# uncorrectly-masked: 73.0198323726654
# uncorrectly-masked: 93.81327033042908
# correctly-masked: 70.2103316783905
# uncorrectly-masked: 81.5485417842865
# correctly-masked: 89.30660486221313
# uncorrectly-masked: 94.22632455825806
# uncorrectly-masked: 51.382845640182495
# correctly-masked: 81.1023473739624
# correctly-masked: 89.96027708053589
# uncorrectly-masked: 75.80896615982056
# not-masked: 99.82452392578125
# not-masked: 99.16274547576904
# not-masked: 99.83807802200317
# not-masked: 99.75497126579285
# not-masked: 98.64590167999268
# not-masked: 99.84872341156006
# not-masked: 99.63716268539429
# not-masked: 97.92710542678833
# uncorrectly-masked: 85.43703556060791
# correctly-masked: 88.1151020526886
# correctly-masked: 98.01610112190247
# correctly-masked: 93.66419315338135
# correctly-masked: 98.65108728408813
# correctly-masked: 97.50723838806152
# correctly-masked: 99.04084205627441
# uncorrectly-masked: 92.8981363773346
# not-masked: 64.3292784690857
# uncorrectly-masked: 96.7073917388916
# not-masked: 99.98107552528381
# uncorrectly-masked: 83.78517627716064
# uncorrectly-masked: 93.5455858707428
# not-masked: 99.75589513778687
# not-masked: 99.42768216133118
# not-masked: 99.3243157863617
# not-masked: 99.48388934135437
# uncorrectly-masked: 86.20676398277283
# not-masked: 99.54689741134644
# uncorrectly-masked: 88.47365379333496
# not-masked: 99.90959167480469
# not-masked: 99.6924102306366
# correctly-masked: 90.94375371932983
# not-masked: 99.31218028068542
# uncorrectly-masked: 64.6899402141571
# not-masked: 99.74496960639954
# not-masked: 99.74421262741089
# uncorrectly-masked: 56.82814121246338
# not-masked: 99.72208738327026
# correctly-masked: 56.647902727127075
# not-masked: 99.4996428489685
# uncorrectly-masked: 60.27565598487854
# not-masked: 99.573814868927
# correctly-masked: 56.91957473754883
# not-masked: 99.32131767272949
# correctly-masked: 92.74850487709045
# not-masked: 99.71945285797119
# correctly-masked: 96.69004678726196
# not-masked: 99.83086585998535
# correctly-masked: 97.75247573852539
# not-masked: 99.99600648880005
# uncorrectly-masked: 82.21059441566467
# correctly-masked: 76.45218968391418
# not-masked: 96.48262858390808
# correctly-masked: 66.12853407859802
# not-masked: 99.94940757751465
# correctly-masked: 49.588096141815186
# correctly-masked: 74.51086044311523
# not-masked: 99.7784972190857
# correctly-masked: 73.96787405014038
# not-masked: 98.67782592773438
# correctly-masked: 67.83270239830017
# not-masked: 97.37923741340637
# not-masked: 94.38732862472534
# correctly-masked: 77.88815498352051
# not-masked: 96.50399684906006
# correctly-masked: 63.4476900100708
# not-masked: 99.9923825263977
# correctly-masked: 64.81962203979492
# correctly-masked: 98.7139880657196
# not-masked: 99.99423027038574
# correctly-masked: 98.60777854919434
# uncorrectly-masked: 61.21572256088257
# correctly-masked: 99.17913675308228
# uncorrectly-masked: 70.90039253234863
# correctly-masked: 97.93262481689453
# uncorrectly-masked: 62.026000022888184
# correctly-masked: 98.56047034263611
# uncorrectly-masked: 79.39944863319397
# correctly-masked: 98.05677533149719
# not-masked: 99.99738931655884
# uncorrectly-masked: 84.77784395217896
# correctly-masked: 99.53166246414185
# correctly-masked: 99.6402382850647
# uncorrectly-masked: 95.03411650657654
# correctly-masked: 99.89163875579834
# correctly-masked: 99.93785619735718
# not-masked: 89.9194598197937
# correctly-masked: 99.75830316543579
# correctly-masked: 99.95137453079224
# correctly-masked: 99.81538653373718
# correctly-masked: 99.79701638221741
# correctly-masked: 50.857025384902954
# uncorrectly-masked: 99.76215958595276
# uncorrectly-masked: 99.73365664482117
# correctly-masked: 99.78461265563965
# uncorrectly-masked: 99.72713589668274
# correctly-masked: 99.75332021713257
# correctly-masked: 77.36408710479736
# uncorrectly-masked: 99.86968636512756
# correctly-masked: 99.87616539001465
# uncorrectly-masked: 53.52267026901245
# uncorrectly-masked: 99.88952279090881
# correctly-masked: 99.85663294792175
# correctly-masked: 69.77241635322571
# uncorrectly-masked: 99.83775615692139
# correctly-masked: 99.83760118484497
# uncorrectly-masked: 99.86414313316345
# correctly-masked: 99.9479591846466
# correctly-masked: 75.77788233757019
# uncorrectly-masked: 99.95132684707642
# uncorrectly-masked: 77.01101303100586
# uncorrectly-masked: 99.91986155509949
# not-masked: 87.66845464706421
# uncorrectly-masked: 59.97608304023743
# uncorrectly-masked: 99.87887740135193
# not-masked: 99.20321702957153
# uncorrectly-masked: 99.1538941860199
# not-masked: 99.5513379573822
# uncorrectly-masked: 99.0021288394928
# not-masked: 97.85994291305542
# uncorrectly-masked: 99.81200098991394
# uncorrectly-masked: 99.52086806297302
# not-masked: 99.99279975891113
# uncorrectly-masked: 54.13939952850342
# uncorrectly-masked: 99.85400438308716
# uncorrectly-masked: 98.75935912132263
# uncorrectly-masked: 99.55553412437439
# uncorrectly-masked: 99.58248138427734
# uncorrectly-masked: 99.71749782562256
# uncorrectly-masked: 99.6557891368866
# not-masked: 98.49618673324585
# uncorrectly-masked: 99.9390721321106
# not-masked: 99.08108711242676
# correctly-masked: 50.00287890434265
# uncorrectly-masked: 99.89122152328491
# uncorrectly-masked: 98.56390953063965
# uncorrectly-masked: 98.17700982093811
# not-masked: 99.87255930900574
# uncorrectly-masked: 59.93528962135315
# uncorrectly-masked: 99.72543120384216
# not-masked: 99.9808132648468
# uncorrectly-masked: 99.38084483146667
# uncorrectly-masked: 98.04623126983643
# uncorrectly-masked: 98.51444959640503
# not-masked: 99.99046325683594
# uncorrectly-masked: 88.22624683380127
# uncorrectly-masked: 97.06385731697083
# not-masked: 99.98621940612793
# uncorrectly-masked: 98.87521862983704
# uncorrectly-masked: 91.2739098072052
# uncorrectly-masked: 99.98583793640137
# uncorrectly-masked: 77.21052169799805
# uncorrectly-masked: 98.43342900276184
# uncorrectly-masked: 75.23931860923767
# uncorrectly-masked: 98.6596405506134
# uncorrectly-masked: 97.21660614013672
# uncorrectly-masked: 97.31692671775818
# uncorrectly-masked: 99.47985410690308
# not-masked: 99.9127209186554
# uncorrectly-masked: 99.5412290096283
# uncorrectly-masked: 99.98283386230469
# uncorrectly-masked: 88.89328837394714
# uncorrectly-masked: 99.78598952293396
# uncorrectly-masked: 99.85707998275757
# uncorrectly-masked: 99.6060311794281
# uncorrectly-masked: 99.82183575630188
# uncorrectly-masked: 98.0780303478241
# uncorrectly-masked: 99.93405938148499
# uncorrectly-masked: 99.47147965431213
# uncorrectly-masked: 99.97010231018066
# uncorrectly-masked: 89.52207565307617
# uncorrectly-masked: 99.98026490211487
# uncorrectly-masked: 99.99058246612549
# uncorrectly-masked: 99.97703433036804
# uncorrectly-masked: 99.9657154083252
# not-masked: 56.801408529281616
# uncorrectly-masked: 99.99324083328247
# not-masked: 53.974246978759766
# uncorrectly-masked: 64.77646231651306
# not-masked: 85.96767783164978
# uncorrectly-masked: 99.93354678153992
# not-masked: 74.70031380653381
# uncorrectly-masked: 99.09913539886475
# not-masked: 96.0554301738739
# not-masked: 96.40322923660278
# not-masked: 99.99279975891113
# uncorrectly-masked: 98.35988283157349
# not-masked: 83.99888873100281
# uncorrectly-masked: 99.97736811637878
# uncorrectly-masked: 99.62124824523926
# uncorrectly-masked: 99.38104748725891
# uncorrectly-masked: 99.62500929832458
# not-masked: 86.212557554245
# not-masked: 99.79122281074524
# not-masked: 99.6913194656372
# not-masked: 99.63005781173706
# uncorrectly-masked: 99.79482293128967
# not-masked: 99.71023201942444
# not-masked: 99.35092329978943
# not-masked: 99.42917823791504
# not-masked: 99.75213408470154
# not-masked: 99.73227381706238
# not-masked: 99.76081848144531
# not-masked: 99.87850785255432
# not-masked: 99.91934895515442
# not-masked: 99.6256947517395
# not-masked: 96.90045118331909
# not-masked: 99.54615235328674
# uncorrectly-masked: 99.59030747413635
# uncorrectly-masked: 86.59998774528503
# not-masked: 99.35778379440308
# not-masked: 99.6669352054596
# not-masked: 99.08960461616516
# not-masked: 99.13712739944458
# not-masked: 98.18912148475647
# not-masked: 99.56777691841125
# not-masked: 98.96453619003296
# uncorrectly-masked: 93.63176822662354
# not-masked: 99.66912269592285
# not-masked: 98.86521697044373
# not-masked: 98.62550497055054
# not-masked: 98.19854497909546
# not-masked: 97.84098267555237
# not-masked: 94.59099769592285
# not-masked: 99.67323541641235
# not-masked: 99.59512948989868
# not-masked: 99.65638518333435
# not-masked: 99.82500672340393
# not-masked: 99.64391589164734
# not-masked: 99.90586638450623
# not-masked: 99.95961785316467
# not-masked: 99.50875639915466
# not-masked: 99.09301400184631
# not-masked: 98.70854020118713
# not-masked: 98.26295375823975
# not-masked: 99.09284710884094
# not-masked: 90.46825170516968
# not-masked: 86.77036166191101
# not-masked: 87.13045120239258
# not-masked: 72.19212651252747
# not-masked: 77.10419297218323
# not-masked: 78.45588326454163
# not-masked: 80.6878387928009
# not-masked: 85.17575263977051
# not-masked: 76.88182592391968
# not-masked: 98.38420152664185
# not-masked: 90.50799608230591
# not-masked: 91.51202440261841
# not-masked: 99.96032118797302
